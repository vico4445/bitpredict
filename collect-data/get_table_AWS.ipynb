# %%
import boto3
import json
import pandas as pd

# %%
client = boto3.client('dynamodb')

response = client.scan(
    TableName='btc_candles_5m',
)

with open("btc_candles_5m.json", "w") as outfile:
    json.dump(response, outfile)

print(response)
# Out:
# {'Items': [{'mts': {'S': '1523301900000'}, 'low': {'S': '6721'}, 'open': {'S': '6736.86545369'}, 'volume': {'S': '45.99811741'}, 'high': {'S': '6738'}, 'close': {'S': '6721.09229148'}}, {'mts': {'S': '1522028700000'}, 'low': {'S': '8373.1'}, 'open': {'S': '8392.6'}, 'volume': {'S': '194.66606906'}, 'high': {'S': '8401'}, 'close': {'S': '8393.1'}}, {'mts': {'S': '1523130300000'}, 'low': {'S': '6972.4'}, 'open': {'S': '6975.4'}, 'volume': {'S': '38.48893769'}, 'high': {'S': '6986.5'}, 'close': {'S': '6985.1'}}, {'mts': {'S': '1522638900000'}, 'low': {'S': '6942'}, 'open': {'S': '6953.8'}, 'volume': {'S': '98.21134936'}, 'high': {'S': '6958.9'}, 'close': {'S': '6952.8'}}, {'mts': {'S': '1523676900000'}, 'low': {'S': '8019.9'}, 'open': {'S': '8020'}, 'volume': {'S': '54.12417572'}, 'high': {'S': '8046'}, 'close': {'S': '8038.2'}}, {'mts': {'S': '1521799200000'}, 'low': {'S': '8474'}, 'open': {'S': '8480'}, 'volume': {'S': '103.95638876'}, 'high': {'S': '8511.5'}, 'close': {'S': '8488.4'}
# ...
